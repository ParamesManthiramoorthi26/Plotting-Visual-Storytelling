# %% [markdown]
# # **Plotting & Visual Storytelling**
#
# ### **Question Title:** **Your First Visualization — Exploring Restaurant**
#
# ### **Tips**
# **Problem Statement:** You are a junior data analyst at a restaurant chain. Your manager has asked you to create a few basic charts to explore customer tipping behavior. In this assignment, you will practice creating simple visualizations using Matplotlib and Seaborn for the first time.

# %% [markdown]
# ### Dataset: Load the Tips dataset directly via Seaborn — no CSV download needed:

# %%
# import Required Library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
print("Required Library Imported")
# Out:
# Required Library Imported

# %%
# Load the Tips dataset directly via Seaborn
tips_df = sns.load_dataset('tips')
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#  Inspect First five rows
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#  Inspect Last five rows
tips_df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
# inspect Missing values
tips_df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %% [markdown]
# * There is no missing values in this data set , so we move to visualization part .

# %% [markdown]
# # Task 1 —  First Matplotlib Chart

# %% [markdown]
# Using Matplotlib, create a bar chart that shows the total tip amount collected on each day of the week.
#
# * x-axis: day,
# * y-axis: total sum of tip
# * Add a title, x-label, and y-label
# * Set the figure size to (8, 5) using `plt.figure(figsize=(8, 5))`
# * Call `plt.show()` to display the chart
#
# **Hint:** Use `tips.groupby("day")["tip"].sum()` to get the total tips per day before plotting.

# %%
# Task 1 :create a bar chart that shows the total tip amount collected on each day of the week.
tot_tip = tips_df.groupby('day')['tip'].sum()
plt.figure(figsize=(8,5))
plt.bar(tot_tip.index,tot_tip)
plt.xlabel('Day')
plt.ylabel('Total sum of tip')
plt.title("Total tip amount collected on each day of the week")
plt.show()
# Out:
# /tmp/ipykernel_459/857065048.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tot_tip = tips_df.groupby('day')['tip'].sum()

# %% [markdown]
# # Task 2 — Seaborn Histogram Using Seaborn

# %% [markdown]
# create a histogram of the tip column to see how tip amounts are distributed across all customers.
# * Set **`bins=20`**
# * Overlay a KDE curve on the histogram
# * Add the title: **"Distribution of Tip Amounts"**
# * Call **`plt.show()`** to display the chart
#
#
# In a markdown cell below your chart, write **2–3** sentences describing what the chart tells you — for example: where most tips fall, whether the distribution is skewed, and what the KDE line adds to the histogram.

# %%
# create a histogram of the tip column to see how tip amounts are distributed across all customers.
plt.figure(figsize=(8,5))
sns.histplot(data=tips_df['tip'] , bins=20 ,kde=True)
plt.title("Distribution of Tip Amounts")
plt.xlabel("Tip Amount")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# * This histogram chart displays tip amount distribution across all cusomers.most of the tip amount fall in **\$2 and \$4** .
#
# * The KDE curve shows the trends of tips based on customers , this distribution clearly shows this right side skewed that means less people gives more tips sometimes.

# %% [markdown]
# # Task 3 — Seaborn Scatter Plot Using Seaborn

# %% [markdown]
# create a scatter plot to explore the relationship between the total bill and the tip amount.
# * x-axis: total_bill,
# * y-axis: tip
# * Color the points by day using the hue parameter
# * Add the title: **"Total Bill vs Tip Amount"**
# * Call `plt.show()` to display the chart
#
#
# In a markdown cell below, write 1–2 sentences describing any pattern you notice — for example, does a higher bill generally lead to a higher tip?

# %%
# create a scatter plot to explore the relationship between the total bill and the tip amount.

plt.figure(figsize=(8,5))
sns.scatterplot(data=tips_df, x='total_bill', y='tip', hue='day')
plt.title("Total Bill vs Tip Amount")
plt.xlabel("Total Bill")
plt.ylabel("Tip Amount")
plt.show()

# %% [markdown]
# * The scatter plot shows a positive relationship between the total bill and the tip amount, meaning that higher bills generally result in higher tips.
# * From the colored points, it appears that Saturday has more observations with higher total bills and higher tip amounts, followed by Thursday.
# * This plot suggests that customers tend to spend more and give higher tips on Saturdays compared to other days.
